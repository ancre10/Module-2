# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Anca Cretu__ Data Analytics

# %% [markdown]
# _I am interested to learn Data Science, and using different different Data science tools_

# %% [markdown]
# My initial code should do simple math: multiplying 4 by 5

# %%
print (4*5)
# Out:
# 20

# %% [markdown]
# -  class Jan
# -  class Feb
#
# 1. Lab Jupyter
# 2. Lab Watson studio
#
# ~Trick to strikethroughs~
#
# |Number of pages|Number of hours|
# |--|--|
# |25|50|
# |35|70|
#
# ***
#
# ![Pic snow.png](attachment:c70e96b4-c43a-48a2-a9d3-77fa3f5ec45c.png)
